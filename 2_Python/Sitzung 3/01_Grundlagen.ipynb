# %% [markdown]
# # Python als "Taschenrechner"

# %% [markdown]
# Python können wir in Notebook-Umgebungen wie Colab oder Jupyter wie einen Taschenrechner verwenden. Dafür geben Zahlen ein und bestätigen durch Shift+Enter

# %%
11
# Out:
# 11

# %%
12.5
# Out:
# 12.5

# %%
2 + 5
# Out:
# 7

# %%
12.5 + 2
# Out:
# 14.5

# %%
12 / 2
# Out:
# 6.0

# %%
12 * 2
# Out:
# 24

# %% [markdown]
# Vorsicht!

# %%
1,0
# Out:
# (1, 0)

# %% [markdown]
# ### Rechnen

# %% [markdown]
# `+`, `-`, `*`, `/`
#
# `//`, `%`, `**`

# %%
42 + 10
# Out:
# 52

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
2 // 3
# Out:
# 0

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
2 ** 5
# Out:
# 32

# %% [markdown]
# ### Text

# %%
"Hallo"
# Out:
# 'Hallo'

# %%
'Hallo'
# Out:
# 'Hallo'

# %% [markdown]
# Text über mehrere Zeilen

# %%
"Hallo
das
ist
ein
Text"
# Out:
#   File "<ipython-input-21-26100bff8e4e>", line 1
#     "Hallo
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""Hallo
das
ist
ein
Text"""
# Out:
# 'Hallo\ndas\nist\nein\nText'

# %%
print("""Hallo
das
ist
ein
Text""")
# Out:
# Hallo
# das
# ist
# ein
# Text

# %% [markdown]
# ### Arithmetik

# %%
2 + 2
# Out:
# 4

# %%
'2' + '4'
# Out:
# '24'

# %%
round(3.1415)
# Out:
# 3

# %%
round(2.71)
# Out:
# 3

# %% [markdown]
# ### Container

# %%
["Eins", "Zwei", "Drei", "Drei"]
# Out:
# ['Eins', 'Zwei', 'Drei', 'Drei']

# %%
list("abcde")
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
("Eins", "Zwei", "Drei", "Drei")
# Out:
# ('Eins', 'Zwei', 'Drei', 'Drei')

# %%
tuple(["Eins", "Zwei", "Drei", "Drei"])
# Out:
# ('Eins', 'Zwei', 'Drei', 'Drei')

# %%
{0,2,1,3,3,3,3}
# Out:
# {0, 1, 2, 3}

# %%
set(["Eins", "Zwei", "Drei", "Drei"])
# Out:
# {'Drei', 'Eins', 'Zwei'}

# %% [markdown]
# ### Wahrheitswerte

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
None
