# %% [markdown]
# # Werte speichern

# %%
x = 42

# %%
y = 18

# %%
42 + 18
# Out:
# 60

# %%
x + y
# Out:
# 60

# %%
text = "Hallo Welt"

# %%
text
# Out:
# 'Hallo Welt'

# %%
print(text)
# Out:
# Hallo Welt

# %%
liste = ["Eins", "Zwei", "Drei"]

# %%
liste
# Out:
# ['Eins', 'Zwei', 'Drei']

# %%
x = 10
y = 15
z = x + y
print(z + 5)
# Out:
# 30

# %% [markdown]
# # Vergleiche

# %%
100 > 10
# Out:
# True

# %%
3 < 4
# Out:
# True

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
2 + True
# Out:
# 3

# %%
True < 10
# Out:
# True

# %%
10 < 10
# Out:
# False

# %%
10 <= 10
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 != 100
# Out:
# True

# %%
not 10 < 20
# Out:
# False

# %%
1 != 2 and 2 != 3
# Out:
# True

# %%
1 != 1 or 2 < 3
# Out:
# True

# %%
0.3 == 0.1 + 0.2
# Out:
# False

# %%
punkte = int(input("Punkte"))
print(punkte >= 50)
# Out:
# Prozent72
# True

# %% [markdown]
# Operationen auf Strings folgen später $\Rightarrow$ zu Container
