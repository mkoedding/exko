# %% [markdown]
# # Dictionary

# %%
noten = {
    "Anna": 1.3,
    "Bernd": 2.0
}

# %%
noten
# Out:
# {'Anna': 1.3, 'Bernd': 2.0}

# %%
noten["Anna"]
# Out:
# 1.3

# %%
noten["Bernd"]
# Out:
# 2.0

# %%
noten = dict()

# %%
noten["Anna"] = 1.3

# %%
noten["Bernd"] = 2.0

# %%
noten
# Out:
# {'Anna': 1.3, 'Bernd': 2.0}

# %%
del noten["Bernd"]

# %%
noten
# Out:
# {'Anna': 1.3, 'Bernd': 2.0}

# %%
noten.items()
# Out:
# dict_items([('Anna', 1.3), ('Bernd', 2.0)])

# %%
for name, note in noten.items():
    print(name, "hat", note)
# Out:
# Anna hat 1.3
# Bernd hat 2.0

# %% [markdown]
# # Set

# %%
zahlen = {1, 3, 2}

# %%
zahlen
# Out:
# {1, 2, 3}

# %%
zahlen = set()

# %%
type(zahlen)
# Out:
# set

# %%
zahlen
# Out:
# set()

# %%
aus_liste = set([1,4,2,2])

# %%
aus_liste
# Out:
# {1, 2, 4}

# %%
zahlen
# Out:
# set()

# %%
zahlen.add(1)

# %%
zahlen.add(2)

# %%
zahlen
# Out:
# {1, 2}

# %%
zahlen.remove(1)

# %%
zahlen
# Out:
# {2}

# %%
zahlen.remove(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 zahlen.remove(1)
#
# KeyError: 1

# %%
zahlen.discard(1)

# %%
a = {1,2,3}
b = {3,4,5}

# %%
a | b
# Out:
# {1, 2, 3, 4, 5}

# %%
a & b
# Out:
# {3}

# %%
a - b
# Out:
# {1, 2}

# %%
a
# Out:
# {1, 2, 3}

# %%
2 in a
# Out:
# True

# %%
2 in (a & b)
# Out:
# False

# %%
i = 7
if i in (a | b):
    print(i, "liegt in", a | b)

# %% [markdown]
# # Tuple

# %%
a = (1,2)

# %%
def teile_mit_rest(x, y):
    return x // y, x % y

# %%
ganz, rest = teile_mit_rest(17,5)

# %%
ganz, rest
# Out:
# (3, 2)

# %%
17 // 5
# Out:
# 3

# %%
17 % 5
# Out:
# 2
