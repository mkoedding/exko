# %%
from manim import *

# %% [markdown]
# Manim nutzt ein 3D Koordinatensystem. D.h. jeder Punkt auf der Ebene wird als 3-Tupel aufgefasst. Der Ursprung hat demnach die Position $(0,0,0)$. Ein Schritt nach `RIGHT` wird dann als $(1,0,0)$ aufgefasst. Die dritte Komponente bleibt immer $0$, solange wir uns auf der Ebene bewegen. In aller Regel werden Koordinaten als `NumPy`-Array beschrieben, wenn wir nicht in Munits (Manim Units, `LEFT`, `RIGHT`, ...) arbeiten.

# %% [markdown]
# Das normale Manim-Fenster umfasst $14,2\overline{2} \times 8$ Munits.

# %%
config.media_width = "80%"
config.verbosity = "WARNING"

# %%
# %%manim -qm Positioning
# class Positioning(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         self.add(plane)
#
#         dot1 = Dot(color=RED)
#         dot2 = Dot(color=BLUE)
#         dot2.next_to(dot1, RIGHT, buff=.1)
#         self.add(dot1, dot2)
#
#         dot3 = Dot(color=YELLOW).shift(RIGHT+2*UP)
#         self.add(dot3)
#
#         square = Square(1)
#         square.shift(3*RIGHT+2*DOWN)
#         self.add(square)
#
#         circle = Circle(1)
#         circle.move_to(np.array([-2,2,0]))
#         self.add(circle)
#
#         dot4 = Dot(color=TEAL)
#         #dot4.align_to(circle, DOWN)
#         dot4.align_to(circle, UP+RIGHT)
#         self.add(dot4)
# Out:
# Manim Community v0.19.0
# [06/17/25 16:54:34] INFO                                                                   ]8;id=439563;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=388464;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#886\886]8;;\
#                              File ready at
#                              '/Users/koedding/PycharmProjects/Videos/mdk/02_farben_positio
#                              nen/media/images/02_farben_positionen/Positioning_ManimCE_v0.
#                              19.0.png'
#                     INFO     Rendered Positioning                                                      ]8;id=624962;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=119897;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py#255\255]8;;\
#                              Played 0 animations

# %%
# %%manim -qm CriticalPoints
#
# class CriticalPoints(Scene):
#     def construct(self):
#         c = Circle(color=GREEN, fill_opacity=0.5)
#         self.add(c)
#
#         self.add(Dot(c.get_critical_point(UP)))
#         self.add(Dot(c.get_critical_point(DR)))
#
#         #s = Square(color=RED, fill_opacity=0.5)
#         #s.move_to(RIGHT, aligned_edge=LEFT)
#         #self.add(s)
# Out:
# Manim Community v0.19.0
# [06/17/25 16:54:45] INFO                                                                   ]8;id=254580;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=995217;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#886\886]8;;\
#                              File ready at
#                              '/Users/koedding/PycharmProjects/Videos/mdk/02_farben_positio
#                              nen/media/images/02_farben_positionen/CriticalPoints_ManimCE_
#                              v0.19.0.png'
#                     INFO     Rendered CriticalPoints                                                   ]8;id=577117;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=568818;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py#255\255]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Grouping
#
# class Grouping(Scene):
#     def construct(self):
#         red_dot = Dot(color=RED)
#         green_dot = Dot(color=GREEN).next_to(red_dot, RIGHT)
#         blue_dot = Dot(color=BLUE).next_to(red_dot, UP)
#         self.add(red_dot, green_dot, blue_dot)
#         #dot_group = VGroup(red_dot, green_dot, blue_dot)
#         #dot_group.to_edge(RIGHT)
#         #self.add(dot_group)
#
#         #circles = VGroup(*[Circle(radius=0.2) for _ in range(10)])
#         #circles.arrange(UP, buff=0.5)
#         #self.add(circles)
#
#         #stars = VGroup(*[Star(color=YELLOW, fill_opacity=1).scale(0.5) for _ in range(20)])
#         #stars.arrange_in_grid(4, 5, buff=0.2)
#         #self.add(stars)
# Out:
# Manim Community v0.19.0
