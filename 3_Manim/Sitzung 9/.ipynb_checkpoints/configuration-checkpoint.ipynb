# %%
from manim import *

# %%
# %%manim SimpleScene
#
# config.background_color = WHITE
# config.frame_width = 9
# config.frame_height = 16
#
# config.pixel_width = 1080
# config.pixel_height = 1920
#
# class SimpleScene(Scene):
#     def construct(self):
#         plane = NumberPlane()
#         t = Triangle(color=PURPLE, fill_opacity=0.5)
#         self.add(plane, t)
# Out:
# Manim Community v0.19.0
# [06/16/25 12:01:02] INFO                                                                   ]8;id=342007;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=397965;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#886\886]8;;\
#                              File ready at
#                              '/Users/koedding/PycharmProjects/Videos/mdk/02_farben_positio
#                              nen/media/images/02_farben_positionen/SimpleScene_ManimCE_v0.
#                              19.0.png'
#                     INFO     Rendered SimpleScene                                                      ]8;id=138837;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=736512;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py#255\255]8;;\
#                              Played 0 animations

# %%
# %%manim -qm ChangedDefaults
#
# config.background_color = BLACK
#
# class ChangedDefaults(Scene):
#     def construct(self):
#         Text.set_default(color=GREEN, font_size=100)
#         t = Text("Hello World!")
#
#         Text.set_default()  # reset previously changed default values
#         t2 = Text("Goodbye!").next_to(t, DOWN)
#         self.add(t, t2)
# Out:
# Manim Community v0.19.0
# [06/16/25 12:01:26] INFO                                                                   ]8;id=47649;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=685661;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene_file_writer.py#886\886]8;;\
#                              File ready at
#                              '/Users/koedding/PycharmProjects/Videos/mdk/02_farben_positio
#                              nen/media/images/02_farben_positionen/ChangedDefaults_ManimCE
#                              _v0.19.0.png'
#                     INFO     Rendered ChangedDefaults                                                  ]8;id=711800;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=967784;file:///Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/manim/scene/scene.py#255\255]8;;\
#                              Played 0 animations
